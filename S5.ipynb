# %% [markdown]
# <a href="https://colab.research.google.com/github/dpkeee/ERA_S5_/blob/main/S5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import  transforms,datasets
import torch.hub as hub

# %%
# CUDA?
cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)
# Out:
# CUDA Available? False

# %%
# Train data transformations
train_transforms = transforms.Compose([
    transforms.RandomApply([transforms.CenterCrop(22), ], p=0.1),
    transforms.Resize((28, 28)),
    transforms.RandomRotation((-15., 15.), fill=0),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
    ])

# Test data transformations
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
    ])

# %%
train_data = datasets.MNIST('../data', train=True, download=True, transform=train_transforms)
test_data = datasets.MNIST('../data', train=False, download=True, transform=test_transforms)

# %%
batch_size = 512

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 2, 'pin_memory': True}

test_loader = torch.utils.data.DataLoader(test_data, **kwargs)
train_loader = torch.utils.data.DataLoader(train_data, **kwargs)

# %%
from utils import return_dataset_images

return_dataset_images(train_loader,8)

# %%
# !pip install torchsummary
# !pip install tqdm
# Out:
# Requirement already satisfied: torchsummary in /usr/local/python/3.10.13/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.13/lib/python3.10/site-packages (4.66.1)

# %%
from model import Net,model_summary,model_test,model_train
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("CUDA Available?", cuda)
model = Net().to(device)
model_summary(model,(1,28,28))
# Out:
# CUDA Available? False
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             288
#             Conv2d-2           [-1, 64, 24, 24]          18,432
#             Conv2d-3          [-1, 128, 10, 10]          73,728
#             Conv2d-4            [-1, 256, 8, 8]         294,912
#             Linear-5                   [-1, 50]         204,800
#             Linear-6                   [-1, 10]             500
# ================================================================
# Total params: 592,660
# Trainable params: 592,660
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 2.26
# Estimated Total Size (MB): 2.93
# ----------------------------------------------------------------

# %%
import torch
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 5

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  model_train(model, device, train_loader, optimizer, criterion)
  model_test(model, device, test_loader, criterion)
  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Test set: Average loss: 1.6998, Accuracy: 4386/10000 (43.86%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Test set: Average loss: 0.1384, Accuracy: 9590/10000 (95.90%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 10
#       8 for epoch in range(1, num_epochs+1):
#       9   print(f'Epoch {epoch}')
# ---> 10   model_train(model, device, train_loader, optimizer, criterion)
#      11   model_test(model, device, test_loader, criterion)
#      12   scheduler.step()
#
# File /workspaces/ERA_S5_/model.py:53, in model_train(model, device, train_loader, optimizer, criterion)
#      50 optimizer.zero_grad()
#      52 # Predict
# ---> 53 pred = model(data)
#      55 # Calculate loss
#      56 loss = criterion(pred, target)
#
# File ~/.python/current/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /workspaces/ERA_S5_/model.py:24, in Net.forward(self, x)
#      22 x = F.relu(F.max_pool2d(self.conv2(x), 2)) #26>24>12 | 3>5>6 | 1>1>2
#      23 x = F.relu(self.conv3(x), 2) # 12>10 | 6>10 | 2>2
# ---> 24 x = F.relu(F.max_pool2d(self.conv4(x), 2)) # 10>8>4 | 10>14>16 | 2>2>4
#      25 x = x.view(-1, 4096) # 4*4*256 = 4096
#      26 x = F.relu(self.fc1(x))
#
# File ~/.python/current/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.python/current/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.python/current/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
from model import draw_graphs
draw_graphs()
